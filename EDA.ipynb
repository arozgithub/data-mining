# %% [markdown]
# # Q1

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Q2

# %%
Example: Age in years. Answer: Discrete, quantitative, ratio
(a) Time in terms of AM or PM.
(b) Brightness as measured by a light meter.
(c) Brightness as measured by people’s judgments.
(d) Angles as measured in degrees between 00 and 3600
(e) Bronze, Silver, and Gold medals as awarded at the Olympics.
(f) Height above sea level.
(g) Number of patients in a hospital.
(h) ISBN numbers for books. (Look up the format on the Web.)
(i) Ability to pass light in terms of the following values: opaque, translucent, transparent.
(j) Military rank.
(k) Distance from the center of campus.
(l) Density of a substance in grams per cubic centimeter.
(m) Coat check number. (When you attend an event, you can often give your coat to someone who,
in turn, gives you a number that you can use to claim your coat when you leave.)

# %%
(a) Binary (nominal,qualitative)
(b) Continuos (quantitative ,ratio)
(c) ordinal (quantitative,discreate)
(d) Continous (quantitative ,ratio)
(e) ordinal (discreate ,qalitative)
(f) Continuous (qantitative ,ratio)
(g) Discreate (quantitative,ratio )
(h) discreate (quantitative ,ratio)
(i) nominal   (qualitative ,discrete)
(j) ordinal   (qualitative,discrete)
(k) continous (quantitaive,ratio)
(l) continous (quantitaive,ratio)
(m) discreate (quantitative ,ratio)

# %% [markdown]
# # Q3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#1. dependent varaibles are species

# %%
#2. independent varaibles are 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'

# %%
df.value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1    5.1            3.5           1.4            0.2           Iris-setosa        1
# 95   5.6            2.7           4.2            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
#                                                                                  ..
# 51   7.0            3.2           4.7            1.4           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# ...

# %%
df.isna().sum() #no missing values
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-22-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-23-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
df.mode().sum()
# Out:
# <ipython-input-28-ebe9e33e35c7>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mode().sum()
# Id               11325.0
# SepalLengthCm        5.0
# SepalWidthCm         3.0
# PetalLengthCm        1.5
# PetalWidthCm         0.2
# dtype: float64

# %%
#from min and max in describe range is given

# %%
 df.std() # std from describe
# Out:
# <ipython-input-27-e4a74f3e500e>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std() # std from describe
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
import seaborn as sns
sns.pairplot(df)

# %%
ax = sns.scatterplot(x='SepalLengthCm',
                y= 'SepalWidthCm',hue="Species",
                data=df)
ax.set_title('SepalLengthCm vs SepalWidthCm')
plt.show()

# %%
sns.histplot(data = df, x = "SepalWidthCm")
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
df_corr = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].dropna().corr()
df_corr
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >
